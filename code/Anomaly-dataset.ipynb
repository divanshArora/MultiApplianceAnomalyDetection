# %%
import pandas as pd

# %%
df = pd.read_csv('/home/divansh/Desktop/Coursework/BTP/MultiApplianceAnomalyDetection/datasets/anomaly-data-ae/redd_home_6.csv', parse_dates=True, index_col='localminute')

# %%
df.head()
# Out:
#                      kitchen_outlets  washer_dryer  stove  electronics  \
# localminute
# 2011-05-22 00:00:00         4.666667           3.0    2.0          0.0
# 2011-05-22 00:00:01         4.777778           3.0    2.0          0.0
# 2011-05-22 00:00:02         4.888889           3.0    2.0          0.0
# 2011-05-22 00:00:03         5.000000           3.0    2.0          0.0
# 2011-05-22 00:00:04         4.888889           3.0    2.0          0.0
#
#                      bathroom_gfi  dishwaser  outlets_unknown  \
# localminute
# 2011-05-22 00:00:00           4.0        0.0             49.0
# 2011-05-22 00:00:01           4.0        0.0             49.0
# 2011-05-22 00:00:02           4.0        0.0             49.0
# 2011-05-22 00:00:03           4.0        0.0             49.0
# 2011-05-22 00:00:04           4.0        0.0             49.0
#
#                      outlets_unknown.1  electric_heat  kitchen_outlets.1  \
# localminute
# ...

# %%
# %matplotlib inline
from matplotlib import rcParams
import matplotlib.pyplot as plt
rcParams['figure.figsize'] = (13, 6)

# %%
small = df['2011-05-24']
small[['air1','refrigerator1']].plot()

# %%
df['2011-05-24'].plot()
